# %%
from glob import glob
import os
import random
from tensorflow import keras
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
keras.utils.get_file(
    os.path.join(os.getcwd(), "data.tar.gz"),
    "https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2",
    extract=True,
    archive_format="tar",
    cache_dir=".",
)

saveto = "../Data/LJSpeech-1.1"
wavs = glob("{}/**/*.wav".format(saveto), recursive=True)

# %%
id_to_text = {}
with open(os.path.join(saveto, "../Data/metadata.csv"), encoding="utf-8") as f:
    for line in f:
        id = line.strip().split("|")[0]
        text = line.strip().split("|")[2]
        id_to_text[id] = text

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("/")[-1].split(".")[0]
        if len(id_to_text[id]) < maxlen:
            data.append({"audio": w, "text": id_to_text[id]})
    return data

# %%
class VectorizeChar:
    def __init__(self, max_len=50):
        self.vocab = (
            ["-", "#", "<", ">"]
            + [chr(i + 96) for i in range(1, 27)]
            + [" ", ".", ",", "?"]
        )
        self.max_len = max_len
        self.char_to_idx = {}
        for i, ch in enumerate(self.vocab):
            self.char_to_idx[ch] = i

    def __call__(self, text):
        text = text.lower()
        text = text[: self.max_len - 2]
        text = "<" + text + ">"
        pad_len = self.max_len - len(text)
        return [self.char_to_idx.get(ch, 1) for ch in text] + [0] * pad_len

    def get_vocabulary(self):
        return self.vocab


max_target_len = 200  # all transcripts in out data are < 200 characters
data = get_data(wavs, id_to_text, max_target_len)
vectorizer = VectorizeChar(max_target_len)
print("vocab size", len(vectorizer.get_vocabulary()))


def create_text_ds(data):
    texts = [_["text"] for _ in data]
    text_ds = [vectorizer(t) for t in texts]
    text_ds = tf.data.Dataset.from_tensor_slices(text_ds)
    return text_ds


def path_to_audio(path):
    # spectrogram using stft
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1)
    audio = tf.squeeze(audio, axis=-1)
    stfts = tf.signal.stft(audio, frame_length=200, frame_step=80, fft_length=256)
    x = tf.math.pow(tf.abs(stfts), 0.5)
    # normalisation
    means = tf.math.reduce_mean(x, 1, keepdims=True)
    stddevs = tf.math.reduce_std(x, 1, keepdims=True)
    x = (x - means) / stddevs
    audio_len = tf.shape(x)[0]
    # padding to 10 seconds
    pad_len = 2754
    paddings = tf.constant([[0, pad_len], [0, 0]])
    x = tf.pad(x, paddings, "CONSTANT")[:pad_len, :]
    return x


def create_audio_ds(data):
    flist = [_["audio"] for _ in data]
    audio_ds = tf.data.Dataset.from_tensor_slices(flist)
    audio_ds = audio_ds.map(
        path_to_audio, num_parallel_calls=tf.data.AUTOTUNE
    )
    return audio_ds


def create_tf_dataset(data, bs=4):
    audio_ds = create_audio_ds(data)
    text_ds = create_text_ds(data)
    ds = tf.data.Dataset.zip((audio_ds, text_ds))
    ds = ds.map(lambda x, y: {"source": x, "target": y})
    ds = ds.batch(bs)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


split = int(len(data) * 0.90)
train_data = data[:split]
test_data = data[split:]
ds = create_tf_dataset(train_data, bs=64)
val_ds = create_tf_dataset(test_data, bs=4)
# Out:
# vocab size 34

# %% [markdown]
# ## Define the Transformer Input Layer
#
# When processing past target tokens for the decoder, we compute the sum of
# position embeddings and token embeddings.
#
# When processing audio features, we apply convolutional layers to downsample
# them (via convolution stides) and process local relationships.

# %%
class TokenEmbedding(layers.Layer):
    def __init__(self, num_vocab=1000, maxlen=100, num_hid=64):
        super().__init__()
        self.emb = tf.keras.layers.Embedding(num_vocab, num_hid)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        x = self.emb(x)
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        return x + positions


class SpeechFeatureEmbedding(layers.Layer):
    def __init__(self, num_hid=64, maxlen=100):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv2 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv3 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        return self.conv3(x)

# %% [markdown]
# ## Transformer Encoder Layer

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# ## Transformer Decoder Layer

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, dropout_rate=0.1):
        super().__init__()
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = layers.LayerNormalization(epsilon=1e-6)
        self.self_att = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.enc_att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.self_dropout = layers.Dropout(0.5)
        self.enc_dropout = layers.Dropout(0.1)
        self.ffn_dropout = layers.Dropout(0.1)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )

    def causal_attention_mask(self, batch_size, n_dest, n_src, dtype):
        """Masks the upper half of the dot product matrix in self attention.

        This prevents flow of information from future tokens to current token.
        1's in the lower triangle, counting from the lower right corner.
        """
        i = tf.range(n_dest)[:, None]
        j = tf.range(n_src)
        m = i >= j - n_src + n_dest
        mask = tf.cast(m, dtype)
        mask = tf.reshape(mask, [1, n_dest, n_src])
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
        )
        return tf.tile(mask, mult)

    def call(self, enc_out, target):
        input_shape = tf.shape(target)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = self.causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        target_att = self.self_att(target, target, attention_mask=causal_mask)
        target_norm = self.layernorm1(target + self.self_dropout(target_att))
        enc_out = self.enc_att(target_norm, enc_out)
        enc_out_norm = self.layernorm2(self.enc_dropout(enc_out) + target_norm)
        ffn_out = self.ffn(enc_out_norm)
        ffn_out_norm = self.layernorm3(enc_out_norm + self.ffn_dropout(ffn_out))
        return ffn_out_norm

# %% [markdown]
# ## Complete the Transformer model
#
# Our model takes audio spectrograms as inputs and predicts a sequence of characters.
# During training, we give the decoder the target character sequence shifted to the left
# as input. During inference, the decoder uses its own past predictions to predict the
# next token.

# %%
class Transformer(keras.Model):
    def __init__(
        self,
        num_hid=64,
        num_head=2,
        num_feed_forward=128,
        source_maxlen=100,
        target_maxlen=100,
        num_layers_enc=4,
        num_layers_dec=1,
        num_classes=10,
    ):
        super().__init__()
        self.loss_metric = keras.metrics.Mean(name="loss")
        self.num_layers_enc = num_layers_enc
        self.num_layers_dec = num_layers_dec
        self.target_maxlen = target_maxlen
        self.num_classes = num_classes

        self.enc_input = SpeechFeatureEmbedding(num_hid=num_hid, maxlen=source_maxlen)
        self.dec_input = TokenEmbedding(
            num_vocab=num_classes, maxlen=target_maxlen, num_hid=num_hid
        )

        self.encoder = keras.Sequential(
            [self.enc_input]
            + [
                TransformerEncoder(num_hid, num_head, num_feed_forward)
                for _ in range(num_layers_enc)
            ]
        )

        for i in range(num_layers_dec):
            setattr(
                self,
                f"dec_layer_{i}",
                TransformerDecoder(num_hid, num_head, num_feed_forward),
            )

        self.classifier = layers.Dense(num_classes)

    def decode(self, enc_out, target):
        y = self.dec_input(target)
        for i in range(self.num_layers_dec):
            y = getattr(self, f"dec_layer_{i}")(enc_out, y)
        return y

    def call(self, inputs):
        source = inputs[0]
        target = inputs[1]
        x = self.encoder(source)
        y = self.decode(x, target)
        return self.classifier(y)

    @property
    def metrics(self):
        return [self.loss_metric]

    def train_step(self, batch):
        """Processes one batch inside model.fit()."""
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        with tf.GradientTape() as tape:
            preds = self([source, dec_input])
            one_hot = tf.one_hot(dec_target, depth=self.num_classes)
            mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
            loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.loss_metric.update_state(loss)
        return {"loss": self.loss_metric.result()}

    def test_step(self, batch):
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        preds = self([source, dec_input])
        one_hot = tf.one_hot(dec_target, depth=self.num_classes)
        mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
        loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        self.loss_metric.update_state(loss)
        return {"loss": self.loss_metric.result()}

    def generate(self, source, target_start_token_idx):
        """Performs inference over one batch of inputs using greedy decoding."""
        bs = tf.shape(source)[0]
        enc = self.encoder(source)
        dec_input = tf.ones((bs, 1), dtype=tf.int32) * target_start_token_idx
        dec_logits = []
        for i in range(self.target_maxlen - 1):
            dec_out = self.decode(enc, dec_input)
            logits = self.classifier(dec_out)
            logits = tf.argmax(logits, axis=-1, output_type=tf.int32)
            last_logit = tf.expand_dims(logits[:, -1], axis=-1)
            dec_logits.append(last_logit)
            dec_input = tf.concat([dec_input, last_logit], axis=-1)
        return dec_input

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("\\")[-1].split(".")[0]
        if len(id_to_text[id]) < maxlen:
            data.append({"audio": w, "text": id_to_text[id]})
    return data

# %%
wavs
# Out:
# ['./datasets/LJSpeech-1.1\\wavs\\LJ001-0001.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0002.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0003.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0004.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0005.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0006.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0007.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0008.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0009.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0010.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0011.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0012.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0013.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0014.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0015.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0016.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0017.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0018.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0019.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0020.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0021.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0022.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0023.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0024.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0025.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0026.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0027.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0028.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0029.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0030.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0031.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0032.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0033.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0034.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0035.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0036.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0037.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0038.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0039.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0040.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0041.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0042.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0043.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0044.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0045.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0046.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0047.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0048.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0049.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0050.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0051.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0052.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0053.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0054.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0055.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0056.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0057.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0058.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0059.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0060.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0061.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0062.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0063.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0064.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0065.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0066.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0067.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0068.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0069.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0070.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0071.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0072.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0073.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0074.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0075.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0076.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0077.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0078.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0079.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0080.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0081.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0082.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0083.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0084.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0085.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0086.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0087.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0088.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0089.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0090.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0091.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0092.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0093.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0094.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0095.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0096.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0097.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0098.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0099.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0100.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0101.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0102.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0103.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0104.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0105.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0106.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0107.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0108.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0109.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0110.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0111.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0112.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0113.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0114.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0115.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0116.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0117.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0118.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0119.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0120.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0121.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0122.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0123.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0124.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0125.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0126.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0127.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0128.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0129.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0130.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0131.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0132.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0133.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0134.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0135.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0136.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0137.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0138.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0139.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0140.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0141.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0142.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0143.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0144.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0145.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0146.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0147.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0148.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0149.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0150.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0151.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0152.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0153.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0154.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0155.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0156.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0157.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0158.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0159.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0160.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0161.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0162.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0163.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0164.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0165.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0166.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0167.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0168.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0169.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0170.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0171.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0172.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0173.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0174.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0175.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0176.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0177.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0178.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0179.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0180.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0181.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0182.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0183.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0184.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0185.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ001-0186.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0001.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0002.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0003.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0004.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0005.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0006.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0007.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0008.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0009.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0010.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0011.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0012.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0013.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0014.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0015.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0016.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0017.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0018.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0019.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0020.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0021.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0022.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0023.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0024.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0025.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0026.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0027.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0028.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0029.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0030.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0031.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0032.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0033.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0034.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0035.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0036.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0037.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0038.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0039.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0040.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0041.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0042.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0043.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0044.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0045.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0046.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0047.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0048.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0049.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0050.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0051.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0052.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0053.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0054.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0055.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-0056.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ002-
wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ004-0129.wav',
#  './datasets/LJSpeech-1.1\\wavs\\LJ004-0130.wav',
#  ...]

# %% [markdown]
# ## Preprocess the dataset

# %% [markdown]
# ## Callbacks to display predictions

# %%
class DisplayOutputs(keras.callbacks.Callback):
    def __init__(
        self, batch, idx_to_token, target_start_token_idx=27, target_end_token_idx=28
    ):
        """Displays a batch of outputs after every epoch

        Args:
            batch: A test batch containing the keys "source" and "target"
            idx_to_token: A List containing the vocabulary tokens corresponding to their indices
            target_start_token_idx: A start token index in the target vocabulary
            target_end_token_idx: An end token index in the target vocabulary
        """
        self.batch = batch
        self.target_start_token_idx = target_start_token_idx
        self.target_end_token_idx = target_end_token_idx
        self.idx_to_char = idx_to_token

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 5 != 0:
            return
        source = self.batch["source"]
        target = self.batch["target"].numpy()
        bs = tf.shape(source)[0]
        preds = self.model.generate(source, self.target_start_token_idx)
        preds = preds.numpy()
        for i in range(bs):
            target_text = "".join([self.idx_to_char[_] for _ in target[i, :]])
            prediction = ""
            for idx in preds[i, :]:
                prediction += self.idx_to_char[idx]
                if idx == self.target_end_token_idx:
                    break
            print(f"target:     {target_text.replace('-','')}")
            print(f"prediction: {prediction}\n")

# %% [markdown]
# ## Learning rate schedule

# %%
class CustomSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self,
        init_lr=0.00001,
        lr_after_warmup=0.001,
        final_lr=0.00001,
        warmup_epochs=15,
        decay_epochs=85,
        steps_per_epoch=203,
    ):
        super().__init__()
        self.init_lr = init_lr
        self.lr_after_warmup = lr_after_warmup
        self.final_lr = final_lr
        self.warmup_epochs = warmup_epochs
        self.decay_epochs = decay_epochs
        self.steps_per_epoch = steps_per_epoch

    def calculate_lr(self, epoch):
        """ linear warm up - linear decay """
        warmup_lr = (
            self.init_lr
            + ((self.lr_after_warmup - self.init_lr) / (self.warmup_epochs - 1)) * epoch
        )
        decay_lr = tf.math.maximum(
            self.final_lr,
            self.lr_after_warmup
            - (epoch - self.warmup_epochs)
            * (self.lr_after_warmup - self.final_lr)
            / (self.decay_epochs),
        )
        return tf.math.minimum(warmup_lr, decay_lr)

    def __call__(self, step):
        epoch = step // self.steps_per_epoch
        return self.calculate_lr(epoch)

    def

# %% [markdown]
# ## Create & train the end-to-end model

# %%
batch = next(iter(val_ds))

# The vocabulary to convert predicted indices into characters
idx_to_char = vectorizer.get_vocabulary()
display_cb = DisplayOutputs(
    batch, idx_to_char, target_start_token_idx=2, target_end_token_idx=3
)  # set the arguments as per vocabulary index for '<' and '>'

model = Transformer(
    num_hid=200,
    num_head=2,
    num_feed_forward=400,
    target_maxlen=max_target_len,
    num_layers_enc=4,
    num_layers_dec=1,
    num_classes=34,
)
loss_fn = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, label_smoothing=0.1,
)

learning_rate = CustomSchedule(
    init_lr=0.00001,
    lr_after_warmup=0.001,
    final_lr=0.00001,
    warmup_epochs=15,
    decay_epochs=85,
    steps_per_epoch=len(ds),
)
optimizer = keras.optimizers.Adam(learning_rate)
model.compile(optimizer=optimizer, loss=loss_fn)

history = model.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=50)
# Out:
# Epoch 1/50
# 185/185 [==============================] - 74s 377ms/step - loss: 1.7441 - val_loss: 1.6265
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <the the te on tin t a the are t ts ilee to t te t the te oin t t t the oin the tot oin oh ail the th othe t t tare on tene t then ais t an oa and are the oe theeathed ten an oe the aii t ts tlr tol o
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction:
>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he discond the perped to have the was not of the perpear to have of the was not of appeared to have of the was nothe waliothe wathe wathe te wathe wat wathe.>
#
# Epoch 17/50
# 185/185 [==============================] - 70s 378ms/step - loss: 0.8137 - val_loss: 0.8614
# Epoch 18/50
# 185/185 [==============================] - 71s 383ms/step - loss: 0.7769 - val_loss: 0.8101
# Epoch 19/50
# 185/185 [==============================] - 71s 381ms/step - loss: 0.7532 - val_loss: 0.8273
# Epoch 20/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.7534 - val_loss: 0.7797
# Epoch 21/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.7102 - val_loss: 0.7606
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <many factord the commission for on dission for on dission for on dission for on dission for on dission for on discessathethethe.>
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction: <that id that it cone one motious the him to him one motious.>
#
# target:     <it is apparent, however, that oswald was moved by an overriding hostility to his environment.>
# prediction: <it is a parint hoswald was in by is in by in how of right however that how have by in how oswald was in by in how the ten teteteteteteteted.>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he disconted with was not appeared to have been flound the was not appear to have been ful with was not a perpear to waly wathe wionte the wonthe wald te te te the.>
#
# Epoch 22/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.6970 - val_loss: 0.7366
# Epoch 23/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.6657 - val_loss: 0.7195
# Epoch 24/50
# 185/185 [==============================] - 70s 379ms/step - loss: 0.6443 - val_loss: 0.7132
# Epoch 25/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.6420 - val_loss: 0.7044
# Epoch 26/50
# 185/185 [==============================] - 70s 378ms/step - loss: 0.6287 - val_loss: 0.6953
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <many factors were undouba dout be dout be the assassination factors were on desassination factors were on desasassination tion th.>
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction: <that it connic one motives cribed connic one motives.>
#
# target:     <it is apparent, however, that oswald was moved by an overriding hostility to his environment.>
# prediction: <it is a parent hoswald was in by an oswald was in by an oswald was in by an oswald was in both ding hoswald was in boten by t.>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he discontentententented with appeared to have been for pets with orle to have been for perpeared to have been for withe te won woror the wothe wote wothe.>
#
# Epoch 27/50
# 185/185 [==============================] - 71s 383ms/step - loss: 0.6199 - val_loss: 0.6901
# Epoch 28/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.5991 - val_loss: 0.6583
# Epoch 29/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.5675 - val_loss: 0.6447
# Epoch 30/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.5707 - val_loss: 0.6367
# Epoch 31/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.5525 - val_loss: 0.6281
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <many for the assassination dese not were undoubated lee den the commission for on desassination for the assassination for ondop were the assassassinationatinatenasionasionate.>
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction: <that hat him one motive to him one motives.>
#
# target:     <it is apparent, however, that oswald was moved by an overriding hostility to his environment.>
# prediction: <it is apparent hose moved by an oswald was moved by an oswald was moved by an oswald was moved by an oswald werite to his a an by an oswald.>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he destablish meally discont tentented with the was not o have been flo with the was perepear to have been flo with the was pere to have been flo with wis othe he oplle d he.>
#
# Epoch 32/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.5354 - val_loss: 0.6383
# Epoch 33/50
# 185/185 [==============================] - 70s 375ms/step - loss: 0.5392 - val_loss: 0.6253
# Epoch 34/50
# 185/185 [==============================] - 70s 379ms/step - loss: 0.5177 - val_loss: 0.6217
# Epoch 35/50
# 185/185 [==============================] - 71s 380ms/step - loss: 0.5216 - val_loss: 0.6182
# Epoch 36/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.5200 - val_loss: 0.6217
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <many factor on doubtedly involvation for undoubtedly involvation for undoubtedly involvation for undoubted leavation for undoply>
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction: <that it him otive to him otive to pin worke to pinima one motives.>
#
# target:     <it is apparent, however, that oswald was moved by an overriding hostility to his environment.>
# prediction: <it is apparent hoswald was moved by an oswald was moved by an oswald was moved by an over that oswald was move all the by an over that.>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he destablish meal to a people to as not appeared to havel to as not appeared to havel to a pentented with the was proountiong.>
#
# Epoch 37/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.5135 - val_loss: 0.6102
# Epoch 38/50
# 185/185 [==============================] - 70s 378ms/step - loss: 0.4943 - val_loss: 0.6127
# Epoch 39/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.4856 - val_loss: 0.6129
# Epoch 40/50
# 185/185 [==============================] - 70s 379ms/step - loss: 0.5124 - val_loss: 0.6092
# Epoch 41/50
# 185/185 [==============================] - 70s 379ms/step - loss: 0.4878 - val_loss: 0.6076
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <many for the commission for undoubted leadly in though adle in thought he commission for undoubation for the assassination doubtion doubation for the>
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction: <that it had it cammotive motive motive motive motive motive motive motive one motives.>
#
# target:     <it is apparent, however, that oswald was moved by an overriding hostility to his environment.>
# prediction: <it is apparent hostility to his apparenment hostility to his aparenment hostility to his in by an over riding hostilit.>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he destablish meal to a stablish meal to a stablish meal to a people to appear to have been ful world round have been tented with other peopear to have otherothe.>
#
# Epoch 42/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.4937 - val_loss: 0.6063
# Epoch 43/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.4974 - val_loss: 0.6007
# Epoch 44/50
# 185/185 [==============================] - 70s 378ms/step - loss: 0.4852 - val_loss: 0.5987
# Epoch 45/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.5273 - val_loss: 0.7097
# Epoch 46/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.5313 - val_loss: 0.5881
# target:     <many factors were undoubtedly involved in oswald#s motivation for the assassination, and the commission does not believe>
# prediction: <many for the assassination doubtedly involvedly in thout had leavation doubtedly in though had leavation for the assassination doubtivation doubtion.>
#
# target:     <that it can ascribe to him any one motive or group of motives.>
# prediction: <that it conne work him otive to him otive to his fribe to his for roupose.>
#
# target:     <it is apparent, however, that oswald was moved by an overriding hostility to his environment.>
# prediction: <it is apparent hoswald was moved by an over righting hostility to his in by an over righting hoswald whever right.>
#
# target:     <he does not appear to have been able to establish meaningful relationships with other people. he was perpetually discontented with the world around him.>
# prediction: <he does not apprets with other to have been full were lationg meal to have been full were lationg apre to have been fother to haver to haver to haver tothithis the.>
#
# Epoch 47/50
# 185/185 [==============================] - 71s 379ms/step - loss: 0.4971 - val_loss: 0.5909
# Epoch 48/50
# 185/185 [==============================] - 70s 378ms/step - loss: 0.4830 - val_loss: 0.5900
# Epoch 49/50
# 185/185 [==============================] - 70s 377ms/step - loss: 0.4654 - val_loss: 0.5910
# Epoch 50/50
# 185/185 [==============================] - 70s 376ms/step - loss: 0.4532 - val_loss: 0.5933

# %%
# serialize weights to HDF5
model.save_weights("../Models/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.save('my_model')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.embeddings.Embedding object at 0x0000025900001B00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.embeddings.Embedding object at 0x0000025900001B00>, because it is not built.
# WARNING:absl:Found untraced functions such as conv1d_6_layer_call_fn, conv1d_6_layer_call_and_return_conditional_losses, conv1d_7_layer_call_fn, conv1d_7_layer_call_and_return_conditional_losses, conv1d_8_layer_call_fn while saving (showing 5 of 345). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_model\assets
# INFO:tensorflow:Assets written to: my_model\assets
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20928/2767724013.py in <module>
# ----> 1 model.save('my_model')
#
# D:\asr\venv\lib\site-packages\keras\engine\training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2144     # pylint: enable=line-too-long
#    2145     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 2146                     signatures, options, save_traces)
#    2147
#    2148   def save_weights(self,
#
# D:\asr\venv\lib\site-packages\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     148     with generic_utils.SharedObjectSavingScope():
#     149       saved_model_save.save(model, filepath, overwrite, include_optimizer,
# --> 150                             signatures, options, save_traces)
#     151
#     152
#
# D:\asr\venv\lib\site-packages\keras\saving\saved_model\save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      92
#      93     # Save all metadata to a separate file in the SavedModel directory.
# ---> 94     metadata = generate_keras_metadata(saved_nodes, node_paths)
#      95
#      96   with tf.io.gfile.GFile(
#
# D:\asr\venv\lib\site-packages\keras\saving\saved_model\save.py in generate_keras_metadata(saved_nodes, node_paths)
#     121               producer=2, min_consumer=1, bad_consumers=[]),
#     122           identifier=node._object_identifier,  # pylint: disable=protected-access
# --> 123           metadata=node._tracking_metadata)  # pylint: disable=protected-access
#     124
#     125   return metadata
#
# D:\asr\venv\lib\site-packages\keras\engine\base_layer.py in _tracking_metadata(self)
#    3076   def _tracking_metadata(self):
#    3077     """Info about this layer to be saved into the SavedModel."""
# -> 3078     return self._trackable_saved_model_saver.tracking_metadata
#    3079
#    3080   def _list_extra_dependencies_for_serialization(self, serialization_cache):
#
# D:\asr\venv\lib\site-packages\keras\saving\saved_model\base_serialization.py in tracking_metadata(self)
#      52     # TODO(kathywu): check that serialized JSON can be loaded (e.g., if an
#      53     # object is in the python property)
# ---> 54     return json_utils.Encoder().encode(self.python_properties)
#      55
#      56   def list_extra_dependencies_for_serialization(self, serialization_cache):
#
# D:\asr\venv\lib\site-packages\keras\saving\saved_model\layer_serialization.py in python_properties(self)
#      35   def python_properties(self):
#      36     # TODO(kathywu): Add python property validator
# ---> 37     return self._python_properties_internal()
#      38
#      39   def _python_properties_internal(self):
#
# D:\asr\venv\lib\site-packages\keras\saving\saved_model\model_serialization.py in _python_properties_internal(self)
#      40     metadata.update(
#      41         saving_utils.model_metadata(
# ---> 42             self.obj, include_optimizer=True, require_config=False))
#      43     return metadata
#      44
#
# D:\asr\venv\lib\site-packages\keras\saving\saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     179                 generic_utils.get_registered_name(model.optimizer.__class__),
#     180             'config':
# --> 181                 model.optimizer.get_config()
#     182         }
#     183       metadata['training_config']['optimizer_config'] = optimizer_config
#
# D:\asr\venv\lib\site-packages\keras\optimizer_v2\adam.py in get_config(self)
#     234     config = super(Adam, self).get_config()
#     235     config.update({
# --> 236         'learning_rate': self._serialize_hyperparameter('learning_rate'),
#     237         'decay': self._initial_decay,
#     238         'beta_1': self._serialize_hyperparameter('beta_1'),
#
# D:\asr\venv\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in _serialize_hyperparameter(self, hyperparameter_name)
#    1052     value = self._hyper[hyperparameter_name]
#    1053     if isinstance(value, learning_rate_schedule.LearningRateSchedule):
# -> 1054       return learning_rate_schedule.serialize(value)
#    1055     if callable(value):
#    1056       return value()
#
# D:\asr\venv\lib\site-packages\keras\optimizer_v2\learning_rate_schedule.py in serialize(learning_rate_schedule)
#    1044       'staircase': True}}
#    1045   """
# -> 1046   return generic_utils.serialize_keras_object(learning_rate_schedule)
#    1047
#    1048
#
# D:\asr\venv\lib\site-packages\keras\utils\generic_utils.py in serialize_keras_object(instance)
#     506         return serialize_keras_class_and_config(
#     507             name, {_LAYER_UNDEFINED_CONFIG_KEY: True})
# --> 508       raise e
#     509     serialization_config = {}
#     510     for key, item in config.items():
#
# D:\asr\venv\lib\site-packages\keras\utils\generic_utils.py in serialize_keras_object(instance)
#     501     name = get_registered_name(instance.__class__)
#     502     try:
# --> 503       config = instance.get_config()
#     504     except NotImplementedError as e:
#     505       if _SKIP_FAILED_SERIALIZATION:
#
# D:\asr\venv\lib\site-packages\keras\optimizer_v2\learning_rate_schedule.py in get_config(self)
#      73   @abc.abstractmethod
#      74   def get_config(self):
# ---> 75     raise NotImplementedError("Learning rate schedule must override get_config")
#      76
#      77   @classmethod
#
# NotImplementedError: Learning rate schedule must override get_config
