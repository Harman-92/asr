# %%
from tensorflow import keras
import tensorflow_datasets as tfds
from glob import glob
import os

# %%
train_ds, train_info = tfds.load('ljspeech', split='train[:90%]', with_info=True)
test_ds, test_info = tfds.load('ljspeech', split='train[90%:]', with_info=True)

# %%
train_info
# Out:
# tfds.core.DatasetInfo(
#     name='ljspeech',
#     full_name='ljspeech/1.1.0',
#     description="""
#     This is a public domain speech dataset consisting of 13,100 short audio clips of
#     a single speaker reading passages from 7 non-fiction books. A transcription is
#     provided for each clip. Clips vary in length from 1 to 10 seconds and have a
#     total length of approximately 24 hours.
#
#     The texts were published between 1884 and 1964, and are in the public domain.
#     The audio was recorded in 2016-17 by the LibriVox project and is also in the
#     public domain.
#     """,
#     homepage='https://keithito.com/LJ-Speech-Dataset/',
#     data_path='C:\\Users\\Harman\\tensorflow_datasets\\ljspeech\\1.1.0',
#     download_size=2.56 GiB,
#     dataset_size=10.73 GiB,
#     features=FeaturesDict({
#         'id': tf.string,
#         'speech': Audio(shape=(None,), dtype=tf.int64),
#         'text': Text(shape=(), dtype=tf.string),
# ...

# %%
for example in train_ds.take(1):
    pass
example['id']
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'LJ021-0170'>

# %%
text_normalized
# Out:
# b'complain that all we have done is unnecessary and subject to great risks.'

# %%
len(test_ds)
# Out:
# 1310

# %%
keras.utils.get_file(
    os.path.join(os.getcwd(), "data.tar.gz"),
    "https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2",
    extract=True,
    archive_format="tar",
    cache_dir=".",
)


saveto = "../Data/LJSpeech-1.1"
wavs = glob("{}/**/*.wav".format(saveto), recursive=True)
# Out:
# ...
#  - ETA: 3:09:17
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19872/1640696454.py in <module>
#       4     extract=True,
#       5     archive_format="tar",
# ----> 6     cache_dir=".",
#       7 )
#       8
#
# D:\asr\venv\lib\site-packages\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     289
#     290   if extract:
# --> 291     _extract_archive(fpath, datadir, archive_format)
#     292
#     293   return fpath
#
# D:\asr\venv\lib\site-packages\keras\utils\data_utils.py in _extract_archive(file_path, path, archive_format)
#     135       with open_fn(file_path) as archive:
#     136         try:
# --> 137           archive.extractall(path)
#     138         except (tarfile.TarError, RuntimeError, KeyboardInterrupt):
# ...

# %%
id_to_text = {}
with open(os.path.join(saveto, "../Data/metadata.csv"), encoding="utf-8") as f:
    for line in f:
        id = line.strip().split("|")[0]
        text = line.strip().split("|")[2]
        id_to_text[id] = text

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("/")[-1].split(".")[0]
        if len(id_to_text[id]) < maxlen:
            data.append({"audio": w, "text": id_to_text[id]})
    return data

# %%
os.path.abspath('../Data/')
# Out:
# 'D:\\asr\\Data'
